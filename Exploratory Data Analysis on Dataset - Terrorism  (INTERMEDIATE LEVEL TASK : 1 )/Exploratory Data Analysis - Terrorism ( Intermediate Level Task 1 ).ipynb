# %% [markdown]
# # LETS GROW MORE
#
# ## LGM VIP - Data Science September-2021
#
# ### Name: SHAUNAK LUNAWAT.
#
# #### Project Name : Exploratory Data Analysis - Terrorism ( Intermediate Level Task 1 )
#
#
# ##### Dataset : https://drive.google.com/file/d/1luTU7xBvI7QAGPbQMxEHcgKUi9d6UeP_/view.

# %%
#importing the required libraries.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("Libraries imported sucessfully")
# Out:
# Libraries imported sucessfully

# %%
df=pd.read_csv('C:/Users/LENOVO/Desktop/LETS GROW MORE TASKS/Shaunak task/BEGINNER TASKS/Exploratory Data Analysis - Terrorism ( Intermediate Level Task 1 )/global_terrorism.csv', encoding = 'latin1')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
# ...

# %%
print("Number of Terrorism Countries wise : ")
df['country_txt'].value_counts()
# Out:
# Number of Terrorism Countries wise :
# Iraq                24636
# Pakistan            14368
# Afghanistan         12731
# India               11960
# Colombia             8306
#                     ...
# Falkland Islands        1
# Vatican City            1
# New Hebrides            1
# Andorra                 1
# North Korea             1
# Name: country_txt, Length: 205, dtype: int64

# %%
print("The country with most terrorism acts is : ", df['natlty1_txt'].value_counts().index[0])
# Out:
# The country with most terrorism acts is :  Iraq

# %%
print("The country with the least terrorism act counts is: ", df['natlty1_txt'].value_counts().index[-1])
# Out:
# The country with the least terrorism act counts is:  Marshall Islands

# %%
print("The Most common types of attack leading to terrorism is : ", df['attacktype1_txt'].value_counts().index[0])
# Out:
# The Most common types of attack leading to terrorism is :  Bombing/Explosion

# %%
plt.subplots(figsize=(20,20))
sns.countplot('attacktype1_txt', data=df, palette='Accent', hue = df['targtype1_txt'])
plt.xticks(rotation=90)
plt.xlabel('TYPE OF ATTACKS')
plt.title("METHODS OF ATTACKING (TARGETS AS HUE)")
plt.show()

# %%
plt.subplots(figsize=(20,10))
sns.countplot('iyear', data=df, palette='CMRmap', edgecolor=sns.color_palette('dark',19))
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Attacks per year')
plt.ylabel('Number of Count')
plt.xlabel('Years')
plt.show()

# %%
print("Maximum Attacks vere witnessed during the year : ",df['iyear'].value_counts().index[0])
# Out:
# Maximum Attacks vere witnessed during the year :  2014

# %%
plt.subplots(figsize=(15,8))
sns.countplot('imonth',data=df,palette='GnBu',edgecolor=sns.color_palette('dark',107))
plt.xticks(rotation=90)
plt.xlabel('Months in a Year')
plt.ylabel('Count of attacks')
plt.title('Number Of Terrorist Attacks')
plt.show()

# %%
print("Maximum Attacks were mostly witnessed during the month of : ",df['imonth'].value_counts().index[0])
print("\n--------------------------------------------------------------------------------------------------- \n")
print("Minimum Attacks were witnessed during the month of : ",df['imonth'].value_counts().index[-2])
# Out:
# Maximum Attacks were mostly witnessed during the month of :  5
#
# ---------------------------------------------------------------------------------------------------
#
# Minimum Attacks were witnessed during the month of :  12

# %%
df['nkill'].value_counts()
# Out:
# 0.0       88149
# 1.0       36576
# 2.0       14147
# 3.0        7738
# 4.0        4961
#           ...
# 122.0         1
# 133.0         1
# 1383.0        1
# 134.0         1
# 953.0         1
# Name: nkill, Length: 205, dtype: int64

# %%
df['nwound'].value_counts()
# Out:
# 0.0      103275
# 1.0       16033
# 2.0       10219
# 3.0        7303
# 4.0        4880
#           ...
# 197.0         1
# 245.0         1
# 211.0         1
# 800.0         1
# 600.0         1
# Name: nwound, Length: 238, dtype: int64

# %%
df_cp=df.copy()
df_cp['affected']= df['nkill']+df['nwound']
df_cp['affected'].value_counts()
# Out:
# 0.0      63297
# 1.0      30157
# 2.0      15278
# 3.0      10273
# 4.0       7549
#          ...
# 392.0        1
# 247.0        1
# 419.0        1
# 422.0        1
# 294.0        1
# Name: affected, Length: 341, dtype: int64

# %%
df1 = df_cp.sort_values(by='affected', ascending=False)[:20]

# %%
heat =df1.pivot_table(index='country_txt', columns='iyear', values='affected')
heat.fillna(0,inplace=True)

# %%
sns.heatmap(heat, cmap='OrRd')
plt.xlabel('YEARS',fontsize=12)
plt.ylabel('Country',fontsize=12)
plt.title('Heatmap with respect to Country and Year displaying the attacked', fontsize=15 )
# Out:
# Text(0.5, 1.0, 'Heatmap with respect to Country and Year displaying the attacked')

# %%
plt.figure(figsize=(20,9))
sns.barplot(df['region_txt'].value_counts()[:10].index,df['region_txt'].value_counts()[:10].values, palette='Paired')
plt.title('N of Terrorist Activities by Region', fontsize=20)
plt.xlabel('Regions', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.show()

# %%
plt.subplots(figsize=(20,9))
sns.barplot(df['country_txt'].value_counts().index[:20],df['country_txt'].value_counts()[:20].values,palette='PiYG')
plt.title('Countries displaying maximum acts of terrorism', fontsize=25)
plt.xlabel('Countries',fontsize=13)
plt.ylabel('Count',fontsize=13)
plt.xticks(rotation= 90)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.barplot(df['city'].value_counts()[1:11].index,df['city'].value_counts()[1:11].values, palette="PuOr")
plt.title('Cities with most acts of terrorism', fontsize=20)
plt.xlabel('Cities',fontsize=16)
plt.ylabel('Count',fontsize=16)
plt.show()

# %%
plt.subplots(figsize=(20,10))
sns.countplot('targtype1_txt', data=df, palette='crest')
plt.xticks(rotation=90)
plt.xlabel('Types of Targets',fontsize=13)
plt.ylabel('COUNTS')
plt.title('Major Targets by Terrorists',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(30,10))
sns.barplot(df['gname'].value_counts()[1:16].values, df['gname'].value_counts()[1:16].index, orient='h', palette='cividis')
plt.title('Number of Terrorist Activities by Terrorist Group', fontsize=25)
plt.xlabel('Groups', fontsize=26)
plt.ylabel('Count', fontsize=26)
plt.show()

# %%
df2 = df[['country_txt','gname','nkill', 'nwound']]
df2 = df2.groupby(['gname','country_txt'], axis=0).sum().sort_values(['nkill', 'nwound'], 
      ascending=False).drop('Unknown').reset_index().head(16)
df2
# Out:
#                                                gname    country_txt    nkill  \
# 0        Islamic State of Iraq and the Levant (ISIL)           Iraq  31058.0
# 1                                            Taliban    Afghanistan  29269.0
# 2                                         Boko Haram        Nigeria  16917.0
# 3                                  Shining Path (SL)           Peru  11595.0
# 4            Liberation Tigers of Tamil Eelam (LTTE)      Sri Lanka  10928.0
# 5                                         Al-Shabaab        Somalia   8176.0
# 6   Farabundo Marti National Liberation Front (FMLN)    El Salvador   8019.0
# 7        Islamic State of Iraq and the Levant (ISIL)          Syria   6883.0
# 8                  Nicaraguan Democratic Force (FDN)      Nicaragua   6630.0
# 9                    Tehrik-i-Taliban Pakistan (TTP)       Pakistan   6014.0
# 10     Revolutionary Armed Forces of Colombia (FARC)       Colombia   5644.0
# ...

# %%
df3 = df.groupby('iyear')['country_txt'].sum().to_frame()
df3
# Out:
#                                              country_txt
# iyear
# 1970   Dominican RepublicMexicoPhilippinesGreeceJapan...
# 1971   United StatesWest Germany (FRG)United StatesUn...
# 1972   PanamaPhilippinesKuwaitSpainArgentinaUnited Ki...
# 1973   ColombiaIrelandDominican RepublicUnited Kingdo...
# 1974   ItalyFranceItalyBoliviaUnited KingdomArgentina...
# 1975   PakistanSpainSpainSpainUnited KingdomNetherlan...
# 1976   TurkeyTurkeyPortugalWest Germany (FRG)United S...
# 1977   JapanJapanJapanFranceFranceSpainItalySpainItal...
# 1978   BrazilEl SalvadorItalyItalyItalyJapanNetherlan...
# 1979   JapanColombiaPhilippinesNicaraguaNicaraguaPeru...
# 1980   West Bank and Gaza StripUnited KingdomUnited K...
# 1981   IrelandEl SalvadorIraqPeruFranceSomaliaSomalia...
# 1982   CanadaGuatemalaIranColombiaColombiaColombiaGua...
# 1983   South AfricaUnited KingdomNetherlandsPeruPeruP...
# 1984   PeruEl SalvadorEl SalvadorWest Bank and Gaza S...
# ...

# %%
casualties_by_year = df.pivot_table(columns='iyear', values=('nkill','nwound'), aggfunc='sum')
casualties_by_year
# Out:
# iyear    1970   1971   1972   1973   1974   1975   1976   1977    1978  \
# nkill   174.0  173.0  566.0  370.0  539.0  617.0  674.0  456.0  1459.0
# nwound  212.0   82.0  409.0  495.0  865.0  617.0  756.0  518.0  1600.0
#
# iyear     1979  ...     2008     2009     2010     2011     2012     2013  \
# nkill   2100.0  ...   9157.0   9273.0   7827.0   8246.0  15497.0  22273.0
# nwound  2506.0  ...  18998.0  19138.0  15947.0  14659.0  25445.0  37688.0
#
# iyear      2014     2015     2016     2017
# nkill   44490.0  38853.0  34871.0  26445.0
# nwound  41128.0  44043.0  40001.0  24927.0
#
# [2 rows x 47 columns]

# %%
df3=df['iyear'].value_counts()[2:20].to_frame()
df3.columns=['Attacks']
data=df.groupby('iyear')['nkill'].sum().to_frame()
df3.merge(data,left_index=True,right_index=True,how='left').plot.bar(width=0.9,color=['pink','lightcoral'])
fig=plt.gcf()
fig.set_size_inches(20,9)
plt.title('Attacks vs Killed')
plt.xlabel('Years')
plt.ylabel('count')
plt.show()

# %% [markdown]
# # RESULTS AND CONCLUSION:
#
#
#
# * The highest numbers of attacks are witnessed by the Taliban group followed by ISIL.
#
#
# * 2014 is the year with most number of attacks and Kills.
#
#
# * The 'Middle East and North Africa' is the region with highest number of attacks and Kills.
#
#
# * The country witnessing the most number of attacks and Kills is " IRAQ ".
#
#
# * Highest Number of kills are by the 'Islamic State of Iraq and the Levant (ISIL)' Group
#
#
# * Major terrorists attacks and kills targets are Private citizens and Property.
#
#
# * Highest Number of Kills is due to 'Armed Assault' Attack type.
#
#
# * Highest Number of Attacks are of 'Bombing/Explosion' Attack type
#
#
# * The City with highest Attacks and Kills is 'Baghdad'.
#
#
# * The country with the least terrorism act counts is:  Marshall Islands
