# %% [markdown]
# # LETS GROW MORE
#
# ## LGM VIP - Data Science September-2021
#
# ### Name: SHAUNAK LUNAWAT.
#
# #### Project Name : PREDICTION USING DECISION TREE ALGORITHM ( INTERMEDIATE LEVEL TASK:2 ) .
#
# DATASET : http://archive.ics.uci.edu/ml/datasets/Iris
#
# ABOUT DATASET : The iris data set contains 50 Sample data about different instances of three categories of iris flowers, namely setosa, versicolor and virginica. The rows being the samples and the columns being: Sepal Length, Sepal Width, Petal Length and Petal Width. This data set measures four features (attributes of the iris flowers, namely the length width of sepal, and the length and width of petal) for different instances of iris flowers and identfies the category of each instance. In this data we will predict the class of flowers based on these parameters and train the model based on these features accordingly.

# %% [markdown]
# STEP 1) IMPORTING LIBRARIES.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn.decomposition import PCA


import warnings
warnings.filterwarnings('ignore')
print("Libraries imported succesfully")
# Out:
# Libraries imported succesfully

# %% [markdown]
# STEP 2.1) IMPORT DATASET.

# %%
df= pd.read_csv("C:/Users/LENOVO/Desktop/LETS GROW MORE TASKS/BEGINNER LEVEL/LGMVIP-DataScience-main/01 Beginner Level Task/Task 1-Iris Flowers Classification ML Project/iris.data",
                names = "Sepal_Length Sepal_Width Petal_Length Petal_Width Species".split())
df.head(10)
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %% [markdown]
# STEP 2.2) DATA INFORMATION.

# %%
df.info()
print("-------------------------------------------------------------------------------------------------")
print("\n")
print("Total attributes = ")
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_Length  150 non-null    float64
#  1   Sepal_Width   150 non-null    float64
#  2   Petal_Length  150 non-null    float64
#  3   Petal_Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# -------------------------------------------------------------------------------------------------
#
#
# Total attributes =
# (150, 5)

# %% [markdown]
# STEP 3) STATICAL ANALYSIS.

# %%
df.describe(include='all')
# Out:
#         Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species
# count     150.000000   150.000000    150.000000   150.000000             150
# unique           NaN          NaN           NaN          NaN               3
# top              NaN          NaN           NaN          NaN  Iris-virginica
# freq             NaN          NaN           NaN          NaN              50
# mean        5.843333     3.054000      3.758667     1.198667             NaN
# std         0.828066     0.433594      1.764420     0.763161             NaN
# min         4.300000     2.000000      1.000000     0.100000             NaN
# 25%         5.100000     2.800000      1.600000     0.300000             NaN
# 50%         5.800000     3.000000      4.350000     1.300000             NaN
# 75%         6.400000     3.300000      5.100000     1.800000             NaN
# max         7.900000     4.400000      6.900000     2.500000             NaN

# %%
df.isnull().sum()
# Out:
# Sepal_Length    0
# Sepal_Width     0
# Petal_Length    0
# Petal_Width     0
# Species         0
# dtype: int64

# %%
df.mean()
# Out:
# Sepal_Length    5.843333
# Sepal_Width     3.054000
# Petal_Length    3.758667
# Petal_Width     1.198667
# dtype: float64

# %%
df.median()
# Out:
# Sepal_Length    5.80
# Sepal_Width     3.00
# Petal_Length    4.35
# Petal_Width     1.30
# dtype: float64

# %%
df.std()
# Out:
# Sepal_Length    0.828066
# Sepal_Width     0.433594
# Petal_Length    1.764420
# Petal_Width     0.763161
# dtype: float64

# %%
df.var()
# Out:
# Sepal_Length    0.685694
# Sepal_Width     0.188004
# Petal_Length    3.113179
# Petal_Width     0.582414
# dtype: float64

# %%
sns.countplot(df['Species'])
# Out:
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %%
df['Species'].value_counts().plot(kind='pie', autopct="%.1f%%")
# Out:
# <AxesSubplot:ylabel='Species'>

# %% [markdown]
# STEP 4) DATA VISUALIZATION.

# %%
# 1) CREATING PAIRPLOT.
x = sns.pairplot(df, hue ="Species", markers = '*' )
plt.show(x)

# %% [markdown]
# * Setosa is linearly seperable but versicolor and virginica are overlapping

# %%
# CREATING HISTOGRAM.
df.hist(figsize=(10,10),color="lightcoral")
plt.show()

# %%
# 3) CREATING BOX PLOT.
df.plot(kind='box',figsize=(8,5), vert=False , color=("navy"));

# %% [markdown]
# * Sepal Width seems to have outliers.

# %%
grid = sns.FacetGrid(df, col="Species");
grid.map(sns.scatterplot, "Sepal_Length","Petal_Width", alpha=.9 ,color=("coral"));
grid.add_legend()

# %% [markdown]
# STEP 5 ) CORRELATION MATRIX

# %%
corr = df.corr ()
corr
# Out:
#               Sepal_Length  Sepal_Width  Petal_Length  Petal_Width   Species
# Sepal_Length      1.000000    -0.109369      0.871754     0.817954  0.782561
# Sepal_Width      -0.109369     1.000000     -0.420516    -0.356544 -0.419446
# Petal_Length      0.871754    -0.420516      1.000000     0.962757  0.949043
# Petal_Width       0.817954    -0.356544      0.962757     1.000000  0.956464
# Species           0.782561    -0.419446      0.949043     0.956464  1.000000

# %%
fig,ax = plt.subplots(figsize=(5,4))
sns.heatmap(corr, annot = True , ax = ax, cmap = 'Greens')
plt.show()

# %% [markdown]
# STEP 6) Label Encoder.
#
# * Machines understand data only in numeric form so we need to convert all categorical data to numerical data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
df
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# STEP 7) CREATING THE MODEL.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score

a = df.iloc[:, 1:-1].values
b = df.iloc[:, -1].values
print("Successfully Done")
# Out:
# Successfully Done

# %%
#Split data in training and test set

a_train, a_test, b_train, b_test = train_test_split(a, b, test_size = 0.1, random_state = 51)
print("Successfully Done")
# Out:
# Successfully Done

# %%
# Defining the decision tree algo

from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(a_train, b_train)

DecisionTreeClassifier()
print("Successfully Done")
# Out:
# Successfully Done

# %%
#Evaluating the model before training on the entire Train set

from sklearn.metrics import accuracy_score
b_prediction = dtree.predict(a_test)
print("Accuracy: ", accuracy_score(b_test, b_prediction) * 100, '%')
# Out:
# Accuracy:  100.0 %

# %%
# Training model on entire train set

from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(a,b)

DecisionTreeClassifier()
print("Successfully Done")
# Out:
# Successfully Done

# %%
from sklearn.tree import plot_tree

featureName=['sepal length','sepal width','petal length','petal width']
className=['Iris-Setosa','Iris-Versicolor','Iris-virginica']

fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (10,10), dpi = 800)

output = plot_tree(dtree, feature_names = featureName, class_names = className, filled = True);
for v in output:
    arrow = v.arrow_patch
    if arrow is not None:
        arrow.set_edgecolor('BLACK')
        arrow.set_linewidth(3.5)
fig.savefig('image.png')

# %%
dTREE = {'y_Actual': test_y,
        'y_Predicted': y_pred
        }

df = pd.DataFrame(data)
df.reset_index(inplace = True, drop = True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-25adafc2ed98> in <module>
# ----> 1 data = {'y_Actual': test_y,
#       2         'y_Predicted': y_pred
#       3         }
#       4
#       5 df = pd.DataFrame(data)
#
# NameError: name 'test_y' is not defined
